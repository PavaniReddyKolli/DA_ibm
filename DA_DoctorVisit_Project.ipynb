# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("DoctorVisits - DA.csv")
print(df.head())
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %% [markdown]
# # load the Dataset and display first 15 rows

# %%
df=pd.read_csv("DoctorVisits - DA.csv")
print(df.head(15))
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %% [markdown]
# # column name,count,data type and overall memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# # find out total number of peoples based on their count of illness

# %%
df["illness"].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %% [markdown]
# # count the peoples based on gender

# %%
df["gender"].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %%
df["age"]=df["age"]*100
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  19.0    0.55        1        4       1
# 1              2       1  female  19.0    0.45        1        2       1
# 2              3       1    male  19.0    0.90        3        0       0
# 3              4       1    male  19.0    0.15        1        0       0
# 4              5       1    male  19.0    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  22.0    0.55        0        0       0
# 5186        5187       0    male  27.0    1.30        0        0       1
# 5187        5188       0  female  37.0    0.25        1        0       1
# 5188        5189       0  female  52.0    0.65        0        0       0
# 5189        5190       0    male  72.0    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df["income"]=df["income"]*10000
df
# Out:
#       Unnamed: 0  visits  gender   age   income  illness  reduced  health  \
# 0              1       1  female  19.0   5500.0        1        4       1
# 1              2       1  female  19.0   4500.0        1        2       1
# 2              3       1    male  19.0   9000.0        3        0       0
# 3              4       1    male  19.0   1500.0        1        0       0
# 4              5       1    male  19.0   4500.0        2        5       1
# ...          ...     ...     ...   ...      ...      ...      ...     ...
# 5185        5186       0  female  22.0   5500.0        0        0       0
# 5186        5187       0    male  27.0  13000.0        0        0       1
# 5187        5188       0  female  37.0   2500.0        1        0       1
# 5188        5189       0  female  52.0   6500.0        0        0       0
# 5189        5190       0    male  72.0   2500.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %% [markdown]
# # visualize and analyse the maximum,minimum and medium income

# %%
y=list(df.income)
plt.boxplot(y)
plt.show()

# %% [markdown]
# # find the number of days of reduced activity of male and female seperatly due to illness

# %%
df.groupby(['gender','reduced']).mean()
# Out:
# C:\Users\sivar\AppData\Local\Temp\ipykernel_40248\1883727358.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['gender','reduced']).mean()
#                  Unnamed: 0    visits        age        income   illness  \
# gender reduced
# female 0        2524.038512  0.229322  46.575492   4827.352298  1.462144
#        1        1985.768421  0.400000  32.568421   5421.052632  2.242105
#        2        1622.618182  0.672727  39.145455   5601.818182  2.236364
#        3         997.311111  1.333333  40.311111   5160.000000  2.733333
#        4        1237.740741  0.851852  45.888889   4666.666667  2.222222
#        5        1169.055556  1.444444  40.166667   6144.444444  2.222222
#        6        1382.545455  1.363636  42.636364   6227.272727  2.363636
# ...

# %%
#missing values
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # find the correlation between variables in the given dataset correlation between different variables

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# C:\Users\sivar\AppData\Local\Temp\ipykernel_40248\1782243109.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >

# %% [markdown]
# # Analyze how the income of a patient affects the no. of visits to the hospital

# %%
#relation between income and visits
plt.figure(figsize=(10,10))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# # count and visualize the number of males and females affected by illness

# %%
#number of males and females affected by illness
sns.histplot(df.gender,bins=2)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %% [markdown]
# # visualize the percentage of people getting govt health insurance due to low income,due to old age and also the percentage of people having private health insurance

# %%
# % of people getting govt insurance due to low income
label=['yes','no']
Y=df[df['freepoor']=='yes']
N=df[df['freepoor']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt health insurance due to low income")
plt.show()
# % of people having private insurance
Y=df[df['private']=='yes']
N=df[df['private']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people having private health insurance")
plt.show()
# % of people getting govt insurance due to old age,disability or veteran status
Y=df[df['freerepat']=='yes']
N=df[df['freerepat']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title(" % of people getting govt insurance due to old age,disability or veteran status")
plt.show()

# %% [markdown]
# # plot a horizental bar chart to analyze the reduced days of activity due to illness based on Gender

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
#calculate the bar chart
plt.barh(db['gender'],db['reduced'],color=['cornflowerblue','lightseagreen'])
#adding the aesthetics
plt.title('Bar Chart')
plt.xlabel('Reduced activity')
plt.ylabel('gender')
#show the plot
plt.show()
